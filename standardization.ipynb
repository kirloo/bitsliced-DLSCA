# %%
from data import get_mean_std
import json

# %%
TRACE_START = 1150
TRACE_END = 1600

mean, std = get_mean_std(TRACE_START, TRACE_END)

figures = {
    "trace_start" : TRACE_START,
    "trace_end" : TRACE_END,
    "training_traces_mean" : mean.item(),
    "training_traces_std" : std.item(),
}

with open(f"misc/standardization/trace{TRACE_START}_{TRACE_END}.json", 'w') as f:
    json.dump(figures, f)
